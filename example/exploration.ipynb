# %%
# Required to load columns with extension types
import elbow.dtypes

import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# Load the table from parquet. Print the column names and pandas types.
#
# > Note, not all types are preserved when converting parquet to pandas. In particular, strings are mapped to objects and ints with `None` to float with `NaN`.

# %%
df = pd.read_parquet("tables/bids-examples.parquet")

print(f"Shape: ", df.shape)
print(
    "Columns:\n"
    + "\n".join(f"  {name}: {typ}" for name, typ in df.dtypes.to_dict().items())
)
# Out:
# Shape:  (10225, 41)
# Columns:
#   dataset: object
#   dataset_path: object
#   dataset_description: json
#   sub: object
#   ses: object
#   sample: object
#   task: object
#   acq: object
#   ce: object
#   trc: object
#   stain: object
#   rec: object
#   dir: object
#   run: float64
#   mod: object
#   echo: float64
#   flip: float64
#   inv: float64
#   mt: object
#   part: object
#   proc: object
#   hemi: object
#   space: object
#   split: object
#   recording: object
#   chunk: float64
#   atlas: object
#   res: object
#   den: object
#   label: object
#   desc: object
#   datatype: object
#   suffix: object
#   ext: object
#   entities: json
#   sidecar: json
#   image_header: json
#   image_affine: ndarray
#   file_path: object
#   link_target: object
#   mod_time: float64

# %% [markdown]
# Sort the dataset. By default, the rows of the dataset may be in arbitrary order.
#
# Then display the first few rows.

# %%
df = df.sort_values(["dataset", "sub", "ses", "task", "run"])

# %%
df.head(4)
# Out:
#      dataset                                       dataset_path
# 3950  7t_trt  /ocean/projects/med220004p/clane2/code/bids2ta...  \
# 3954  7t_trt  /ocean/projects/med220004p/clane2/code/bids2ta...
# 3953  7t_trt  /ocean/projects/med220004p/clane2/code/bids2ta...
# 3955  7t_trt  /ocean/projects/med220004p/clane2/code/bids2ta...
#
#                              dataset_description sub ses sample  task
# 3950  {'BIDSVersion': '1.8.0', 'Name': '7t_trt'}  01   1   None  rest  \
# 3954  {'BIDSVersion': '1.8.0', 'Name': '7t_trt'}  01   1   None  rest
# 3953  {'BIDSVersion': '1.8.0', 'Name': '7t_trt'}  01   1   None  rest
# 3955  {'BIDSVersion': '1.8.0', 'Name': '7t_trt'}  01   1   None  rest
#
#             acq    ce   trc stain   rec   dir  run   mod  echo  flip  inv
# 3950  fullbrain  None  None  None  None  None  1.0  None   NaN   NaN  NaN  \
# 3954  fullbrain  None  None  None  None  None  1.0  None   NaN   NaN  NaN
# 3953  fullbrain  None  None  None  None  None  2.0  None   NaN   NaN  NaN
# 3955  fullbrain  None  None  None  None  None  2.0  None   NaN   NaN  NaN
#
#         mt  part  proc  hemi space split recording  chunk atlas   res   den
# 3950  None  None  None  None  None  None      None    NaN  None  None  None  \
# 3954  None  None  None  None  None  None      None    NaN  None  None  None
# 3953  None  None  None  None  None  None      None    NaN  None  None  None
# 3955  None  None  None  None  None  None      None    NaN  None  None  None
#
#      label  desc datatype  suffix      ext
# 3950  None  None     func  physio  .tsv.gz  \
# 3954  None  None     func    bold  .nii.gz
# 3953  None  None     func    bold  .nii.gz
# 3955  None  None     func  physio  .tsv.gz
#
#                                                entities
# 3950  {'sub': '01', 'ses': '1', 'task': 'rest', 'acq...  \
# 3954  {'sub': '01', 'ses': '1', 'task': 'rest', 'acq...
# 3953  {'sub': '01', 'ses': '1', 'task': 'rest', 'acq...
# 3955  {'sub': '01', 'ses': '1', 'task': 'rest', 'acq...
#
#                                                 sidecar image_header
# 3950  {'StartTime': 0, 'SamplingFrequency': 100, 'Co...         None  \
# 3954  {'CogAtlasID': 'https://www.cognitiveatlas.org...         None
# 3953  {'CogAtlasID': 'https://www.cognitiveatlas.org...         None
# 3955  {'StartTime': 0, 'SamplingFrequency': 100, 'Co...         None
#
#      image_affine                                          file_path
# 3950          nan  /ocean/projects/med220004p/clane2/code/bids2ta...  \
# 3954          nan  /ocean/projects/med220004p/clane2/code/bids2ta...
# 3953          nan  /ocean/projects/med220004p/clane2/code/bids2ta...
# 3955          nan  /ocean/projects/med220004p/clane2/code/bids2ta...
#
#      link_target      mod_time
# 3950        None  1.683159e+09
# 3954        None  1.683159e+09
# 3953        None  1.683159e+09
# 3955        None  1.683159e+09

# %% [markdown]
# Count the number of non-null entries per column.

# %%
column_counts = df.count(axis=0)
column_counts
# Out:
# dataset                10225
# dataset_path           10225
# dataset_description    10201
# sub                    10225
# ses                     3506
# sample                    16
# task                    7992
# acq                      422
# ce                         0
# trc                        0
# stain                      8
# rec                       58
# dir                        3
# run                     6736
# mod                        1
# echo                     541
# flip                      53
# inv                       20
# mt                        25
# part                      16
# proc                     208
# hemi                      83
# space                    301
# split                      0
# recording                  5
# chunk                      8
# atlas                      0
# res                       84
# den                        0
# label                     84
# desc                     280
# datatype                8836
# suffix                 10163
# ext                    10225
# entities               10225
# sidecar                 5023
# image_header             165
# image_affine           10225
# file_path              10225
# link_target                0
# mod_time               10225
# dtype: int64

# %% [markdown]
# We see that some BIDS entities never appear in any of the example datasets.

# %%
column_counts[column_counts == 0]
# Out:
# ce             0
# trc            0
# split          0
# atlas          0
# den            0
# link_target    0
# dtype: int64

# %% [markdown]
# Count the number of files per dataset (with sidecar metadata and/or image header metadata).
#
# > Note, most of the image files in the bids-examples dataset have empty headers.

# %%
df.groupby("dataset").agg(
    {"file_path": "count", "sidecar": "count", "image_header": "count"}
)
# Out:
#                                         file_path  sidecar  image_header
# dataset
# 7t_trt                                        635      350             0
# asl001                                          4        2             0
# asl002                                          5        3             0
# asl003                                          5        3             0
# asl004                                          6        4             0
# asl005                                          5        3             0
# ds000001-fmriprep                             420       52             0
# ds000117                                     1089      641             0
# ds000246                                       32       22             0
# ds000247                                      100       70             0
# ds000248                                       11        4             0
# ds001                                         128       48             0
# ds002                                         238      102             0
# ds003                                          52       13             0
# ds004332                                       58       58             0
# ds005                                         128       48             0
# ds006                                         384      164             0
# ds007                                         276      118             0
# ds008                                         197       84             0
# ds009                                         360      144             0
# ds011                                         196       84             0
# ds051                                         245      102             0
# ds052                                         142       52             0
# ds101                                         105       42             0
# ds102                                         130       52             0
# ds105                                         148       71             0
# ds107                                         245       98             0
# ds108                                         442      204             0
# ds109                                         174       69             0
# ds110                                         396      180             0
# ds113b                                        312      156             0
# ds114                                         160      100             0
# ds116                                         238      102             0
# ds210                                         300      300             0
# eeg_cbm                                        80       20             0
# eeg_ds000117                                  320      208             0
# eeg_ds003645s_hed                              18       12             0
# eeg_ds003645s_hed_inheritance                  14       12             0
# eeg_ds003645s_hed_library                      18       12             0
# eeg_ds003645s_hed_longform                     18       12             0
# eeg_face13                                     70       10             0
# eeg_matchingpennies                            42       35             0
# eeg_rest_fmri                                  45       45             0
# eeg_rishikesh                                 120       80             0
# fnirs_automaticity                            672      192             0
# fnirs_tapping                                  25        5             0
# genetics_ukbb                                 112       42             0
# hcp_example_bids                                5        3             0
# ieeg_epilepsy                                  21       10             0
# ieeg_epilepsy/derivatives/brainvisa            12        0             0
# ieeg_epilepsyNWB                               15        4             0
# ieeg_epilepsyNWB/derivatives/brainvisa         12        0             0
# ieeg_epilepsy_ecog                             18        4             0
# ieeg_filtered_speech                           49       28             0
# ieeg_motorMiller2007                          112       48             0
# ieeg_visual                                    20       11             2
# ieeg_visual_multimodal                        101       87             0
# micr_SEM                                        5        5             0
# micr_SEMzarr                                    3        3             0
# micr_SPIM                                      10       10             0
# motion_dualtask                               355      195             0
# motion_spotrotation                           100       55             0
# motion_systemvalidation                        27       12             0
# pet001                                          4        4             1
# pet002                                          8        8             0
# pet003                                          3        2             0
# pet004                                          3        3             0
# pet005                                          5        5             2
# qmri_irt1                                       4        4             0
# qmri_irt1/derivatives/qMRLab                    2        2             0
# qmri_megre                                      8        8             0
# qmri_mese                                      32       32             0
# qmri_mese/derivatives/qMRLab                    3        3             0
# qmri_mp2rage                                    5        4             0
# qmri_mp2rage/derivatives/pymp2rage              2        2             0
# qmri_mp2rageme                                 11       11             0
# qmri_mp2rageme/derivatives/pymp2rage            4        4             0
# qmri_mpm                                       53       53             0
# qmri_mpm/derivatives/hmri                       8        8             0
# qmri_mtsat                                      5        5             0
# qmri_mtsat/derivatives/qMRLab                   5        5             0
# qmri_qsm                                        2        2             0
# qmri_qsm/derivatives/qMRLab                     1        1             0
# qmri_sa2rage                                    2        2             0
# qmri_sa2rage/derivatives/sa2rage                1        1             0
# qmri_tb1tfl                                     2        2             0
# qmri_vfa                                        4        4             0
# qmri_vfa/derivatives/qMRLab                     3        3             0
# synthetic                                     110       80            40
# synthetic/derivatives/fmriprep                150       60           120
